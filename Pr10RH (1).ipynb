# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.patches as mpatches

# %%
red=mpatches.Patch(color='red',label='The Red Data')

# %%
plt.legend(handles=[red])
plt.show()

# %%
import matplotlib.lines as mlines

# %%
blue=mlines.Line2D([],[],color='blue',marker='+',markersize=15,label='Blue Plus')
plt.legend(handles=[blue])
plt.show()

# %%
plt.subplot(211)
plt.plot([1,2,3],label='First')
plt.plot([3,2,1],label='Second')

# %%
import matplotlib.pyplot as plt
import numpy as np

city=['Delhi','Beijing','Washington','Tokyo','Moscow']
Gender=['Male','Female']
pos=np.arange(len(city))
bar_width=0.35
Happiness_Index_Male=[60,40,70,65,85]
Happiness_Index_Female=[30,60,70,55,75]

plt.bar(pos,Happiness_Index_Male,color='blue',edgecolor='black')
plt.bar(pos,Happiness_Index_Female,color='pink',edgecolor='black')
plt.xticks(pos,city)
plt.xlabel('City',fontsize=16)
plt.ylabel('Happiness_Index',fontsize=16)
plt.title('Group Barchart - Happiness index across cities By Gender',fontsize=18)
plt.label(Gender,loc=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-b48adda34eae> in <module>
#      15 plt.ylabel('Happiness_Index',fontsize=16)
#      16 plt.title('Group Barchart - Happiness index across cities By Gender',fontsize=18)
# ---> 17 plt.label(Gender,loc=2)
#      18 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'label'

# %%
import matplotlib.pyplot as plt

import numpy as np


t = np.arange(0., 5.0, 0.2)


plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()


def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)


n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt


slice=[10,2,7,5]
activities=['Sleeping','Eating','Study','Waste']
cols=['r','g','b','w']

plt.pie(slice,
        labels=activities,
        colors=cols,
        startangle=90,
        shadow=True,
        explode=(0,0,0.1,0),
        autopct='%0.2f%%')

plt.title('GRACE:')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t)*np.cos(2*np.pi*t)
t1=np.arange(0.0,5.0,0.1)
t2=np.arange(0.0,5.0,0.02)


plt.plot(t1,f(t1),'bo',t2,f(t2))


plt.plot(t2,np.cos(2*np.pi*t2))
plt.show()

# %%
import matplotlib.pyplot as plt
from array import *
from time import sleep
print("dddd",end=" ")


t=plt.title(input(str("Enter the Student Name :")))

file=open('time_uti.doc','a')
file.write(str(t))
file.write("\n")
sum=0

arr=array('i',[])

val=[1,2,3,4]

for i in val:
    if i==1:
        print("Sleeping Time ::")
        x=int(input())
        arr.append(x)
        pass
    if i==2:
        print("Eating Time ::")
        x=int(input())
        arr.append(x)
        pass
    if i==3:
        print("studying Time ::")
        x=int(input())
        arr.append(x)
        pass
    if i>3:
        arr.append(0)
        break
   
    sum=sum+x
   
    

total_west=24-sum
print("Print Westing time :",total_west)



arr[3]=int(total_west)

slice=list(arr)


activities=['Sleeping','Eating','STudYing/Working','Wasting time']
cols=['c','m','r','b']

u=plt.pie(slice,
        labels=activities,
        colors=cols,
        startangle=90,
        shadow=True,
        explode=(0,0,0,0.1),
        autopct='%0.2f%%')


file=open('time_uti.png','a')
file.write(str(u))

a=plt.show()


print("Bye Bye")
r=str(input("Press any key and Enter to Terminate ->:"))
# Out:
# dddd Enter the Student Name :Prashant SIngh
# Sleeping Time ::
# 10
# Eating Time ::
# 3
# studying Time ::
# 4
# Print Westing time : 7
# Bye Bye
# Press any key and Enter to Terminate ->:

# %%
import matplotlib.pyplot as plt
from matplotlib import *
from matplotlib import style
from array import *


arr=[]

n=int(input("inter the length of array maximum - 5:"))

for i in range(n):
    print("AUS  score  per over :")
    x=int(input())
    arr.append(x)
print(arr)
AUS=list(arr)
print(AUS)

width = [3.0,3.0,3.0,3.0,3.0]

x=[10,20,30,40,50]
x2=[13,23,33,43,53]
IND=[53,111,190,250,352]

plt.bar(x,IND,label="IND",color='b',width=width)
plt.bar(x2,AUS,label="AUS",color='y',width=width)

plt.legend()
    
plt.title("IND VS AUS CWC 2019")    
plt.xlabel("OVER")
plt.ylabel("SCORE")

plt.show()
print(" ")
print(" ")

print("Bye Bye")
r=str(input("Press any key nd Enter to terminate :"))
# Out:
# inter the length of array maximum - 5:5
# AUS  score  per over :
# 23
# AUS  score  per over :
# 55
# AUS  score  per over :
# 77
# AUS  score  per over :
# 55
# AUS  score  per over :
# 34
# [23, 55, 77, 55, 34]
# [23, 55, 77, 55, 34]
#
#
# Bye Bye
# Press any key nd Enter to terminate :
